# %%
import cv2 as cv

move_rectangle = False
BLUE = [255,0,0]

fg = cv.imread('datasetl/form 123.png')
bg = cv.imread('datasetl/form 124.png')
bgCopy = bg.copy()

def mouse(event,x,y,flags,params):
    global move_rectangle, BLUE, fg, bg, bgCopy
    #draw rectangle where x,y is rectangle center
    if event == cv.EVENT_LBUTTONDOWN:
        move_rectangle = True

    elif event == cv.EVENT_MOUSEMOVE:
        bg = bgCopy.copy() #!! your image is reinitialized with initial one
        if move_rectangle:
            cv.rectangle(bg,(x-int(0.5*cols),y-int(0.5*rows)),
            (x+int(0.5*cols),y+int(0.5*rows)),BLUE, -1)

    elif event == cv.EVENT_LBUTTONUP:
        move_rectangle = False
        cv.rectangle(bg,(x-int(0.5*cols),y-int(0.5*rows)),
        (x+int(0.5*cols),y+int(0.5*rows)),BLUE, -1)

if __name__ == '__main__':
    rows, cols = fg.shape[:2]

    cv.namedWindow('draw')
    cv.setMouseCallback('draw', mouse)

    while True:

        cv.imshow('draw', bg)
        k = cv.waitKey(1)

        #waiting for esc to exit
        if k == 27 & 0xFF:
            break

    cv.destroyAllWindows()

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       0.12.0
# appdirs                       1.4.4
# argon2-cffi                   20.1.0
# asgiref                       3.5.0
# astunparse                    1.6.3
# async-generator               1.10
# attrs                         21.2.0
# audioread                     2.1.9
# backcall                      0.2.0
# beautifulsoup4                4.10.0
# bleach                        4.0.0
# bs4                           0.0.1
# cachetools                    4.2.4
# certifi                       2021.5.30
# cffi                          1.14.6
# charset-normalizer            2.0.7
# clang                         5.0
# click                         8.0.3
# cmake                         3.21.3
# colorama                      0.4.4
# comtypes                      1.1.10
# cryptography                  36.0.0
# cycler                        0.10.0
# Cython                        0.29.26
# dataclasses                   0.6
# debugpy                       1.4.1
# decorator                     5.0.9
# defusedxml                    0.7.1
# dill                          0.3.4
# Django                        4.0.1
# django-extensions             3.1.5
# dlib                          19.22.1
# dm-tree                       0.1.6
# easyocr                       1.4.1
# entrypoints                   0.3
# face-recognition              1.3.0
# face-recognition-models       0.3.0
# falcon                        3.0.1
# fire                          0.4.0
# flatbuffers                   1.12
# future                        0.18.2
# gast                          0.4.0
# gevent                        21.8.0
# gin-config                    0.5.0
# google-api-core               2.3.2
# google-api-python-client      2.33.0
# google-auth                   2.3.1
# google-auth-httplib2          0.1.0
# google-auth-oauthlib          0.4.6
# google-cloud-bigquery         2.31.0
# google-cloud-core             2.2.1
# google-crc32c                 1.3.0
# google-pasta                  0.2.0
# google-resumable-media        2.1.0
# googleapis-common-protos      1.54.0
# greenlet                      1.1.2
# grpcio                        1.43.0
# grpcio-status                 1.43.0
# gTTS                          2.2.3
# h11                           0.12.0
# h5py                          3.1.0
# httplib2                      0.20.2
# idna                          3.3
# imageio                       2.9.0
# importlib-metadata            4.6.4
# ipykernel                     6.2.0
# ipyplot                       1.1.0
# ipython                       7.26.0
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# jedi                          0.18.0
# Jinja2                        3.0.1
# joblib                        1.1.0
# jsonschema                    3.2.0
# jupyter                       1.0.0
# jupyter-client                7.0.1
# jupyter-console               6.4.0
# jupyter-core                  4.7.1
# jupyterlab-pygments           0.1.2
# jupyterlab-widgets            1.0.2
# kaggle                        1.5.12
# keras                         2.6.0
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.3.2
# labelImg                      1.8.6
# librosa                       0.8.1
# libzim                        0.0.1
# llvmlite                      0.36.0
# lxml                          4.6.4
# Mako                          1.1.5
# Markdown                      3.3.4
# MarkupSafe                    2.0.1
# matplotlib                    3.4.3
# matplotlib-inline             0.1.2
# mediapipe                     0.8.7.3
# mistune                       0.8.4
# nbclient                      0.5.3
# nbconvert                     6.1.0
# nbformat                      5.1.3
# nest-asyncio                  1.5.1
# networkx                      2.6.3
# neural-structured-learning    1.3.1
# nltk                          3.6.5
# notebook                      6.4.3
# numba                         0.53.0
# numpy                         1.19.5
# oauthlib                      3.1.1
# opencv-contrib-python         4.5.3.56
# opencv-python                 4.5.4.58
# opencv-python-headless        4.5.4.58
# opt-einsum                    3.3.0
# outcome                       1.1.0
# packaging                     21.0
# pandas                        1.3.5
# pandocfilters                 1.4.3
# parso                         0.8.2
# pdf2image                     1.16.0
# pickleshare                   0.7.5
# Pillow                        8.2.0
# pip                           21.2.4
# playsound                     1.3.0
# pooch                         1.5.2
# prometheus-client             0.11.0
# promise                       2.3
# prompt-toolkit                3.0.17
# proto-plus                    1.19.8
# protobuf                      3.19.1
# psutil                        5.8.0
# py-cpuinfo                    8.0.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# PyAudio                       0.2.11
# pybind11                      2.8.1
# pycparser                     2.20
# pygame                        2.0.2
# Pygments                      2.10.0
# PyMuPDF                       1.19.4
# pyOpenSSL                     21.0.0
# pyparsing                     2.4.7
# pypiwin32                     223
# PyQt5                         5.15.6
# PyQt5-Qt5                     5.15.2
# PyQt5-sip                     12.9.0
# pyrsistent                    0.18.0
# pytesseract                   0.3.8
# python-barcode                0.13.1
# python-bidi                   0.4.2
# python-dateutil               2.8.2
# python-slugify                5.0.2
# pyttsx3                       2.90
# pytz                          2021.3
# PyWavelets                    1.1.1
# pywin32                       228
# pywinpty                      0.5.7
# PyYAML                        6.0
# pyzbar                        0.1.8
# pyzmq                         22.2.1
# qrcode                        7.3.1
# qtconsole                     5.2.2
# QtPy                          2.0.0
# regex                         2021.11.10
# requests                      2.26.0
# requests-oauthlib             1.3.0
# resampy                       0.2.2
# rsa                           4.7.2
# scikit-image                  0.18.3
# scikit-learn                  1.0.1
# scipy                         1.7.1
# selenium                      4.1.0
# Send2Trash                    1.5.0
# sentencepiece                 0.1.96
# setuptools                    52.0.0.post20210125
# shortuuid                     1.0.8
# six                           1.15.0
# sniffio                       1.2.0
# sortedcontainers              2.4.0
# sounddevice                   0.4.3
# SoundFile                     0.10.3.post1
# soupsieve                     2.2.1
# SpeechRecognition             3.8.1
# sqlparse                      0.4.2
# tensorboard                   2.7.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.0
# tensorflow                    2.6.0
# tensorflow-addons             0.15.0
# tensorflow-datasets           4.4.0
# tensorflow-estimator          2.6.0
# tensorflow-hub                0.12.0
# tensorflow-metadata           1.5.0
# tensorflow-model-optimization 0.7.0
# tensorflowjs                  3.12.0
# termcolor                     1.1.0
# terminado                     0.9.4
# testpath                      0.5.0
# text-unidecode                1.3
# tf-models-official            2.3.0
# tf-slim                       1.1.0
# tflite-model-maker            0.3.4
# tflite-runtime                2.5.0.post1
# tflite-support                0.3.1
# threadpoolctl                 3.0.0
# tifffile                      2021.8.30
# torch                         1.10.0
# torchaudio                    0.10.0
# torchvision                   0.11.1
# tornado                       6.1
# tqdm                          4.62.2
# traitlets                     5.0.5
# trio                          0.19.0
# trio-websocket                0.9.2
# typeguard                     2.13.3
# typing-extensions             3.7.4.3
# tzdata                        2021.5
# uritemplate                   4.1.1
# urllib3                       1.25.11
# vosk                          0.3.31
# wcwidth                       0.2.5
# webencodings                  0.5.1
# Werkzeug                      2.0.2
# wget                          3.2
# wheel                         0.37.0
# widgetsnbextension            3.5.2
# wikipedia                     1.4.0
# wincertstore                  0.2
# wrapt                         1.12.1
# wsproto                       1.0.0
# zimply                        1.1.4
# zipp                          3.5.0
# zope.event                    4.5.0
# zope.interface                5.4.0
# zstandard                     0.16.0

# %%
# !pip install Flask
# Out:
# Collecting Flask
#   Downloading Flask-2.0.3-py3-none-any.whl (95 kB)
# Requirement already satisfied: Jinja2>=3.0 in c:\programdata\anaconda3\envs\detection\lib\site-packages (from Flask) (3.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in c:\programdata\anaconda3\envs\detection\lib\site-packages (from Flask) (2.0.2)
# Requirement already satisfied: click>=7.1.2 in c:\programdata\anaconda3\envs\detection\lib\site-packages (from Flask) (8.0.3)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\detection\lib\site-packages (from click>=7.1.2->Flask) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\envs\detection\lib\site-packages (from Jinja2>=3.0->Flask) (2.0.1)
# Installing collected packages: itsdangerous, Flask
# Successfully installed Flask-2.0.3 itsdangerous-2.1.0

# %%
# !pip install djangorestframework
# Out:
# Collecting djangorestframework
#   Downloading djangorestframework-3.13.1-py3-none-any.whl (958 kB)
# Requirement already satisfied: django>=2.2 in c:\programdata\anaconda3\envs\detection\lib\site-packages (from djangorestframework) (4.0.1)
# Requirement already satisfied: pytz in c:\programdata\anaconda3\envs\detection\lib\site-packages (from djangorestframework) (2021.3)
# Requirement already satisfied: asgiref<4,>=3.4.1 in c:\programdata\anaconda3\envs\detection\lib\site-packages (from django>=2.2->djangorestframework) (3.5.0)
# Requirement already satisfied: sqlparse>=0.2.2 in c:\programdata\anaconda3\envs\detection\lib\site-packages (from django>=2.2->djangorestframework) (0.4.2)
# Requirement already satisfied: tzdata in c:\programdata\anaconda3\envs\detection\lib\site-packages (from django>=2.2->djangorestframework) (2021.5)
# Installing collected packages: djangorestframework
# Successfully installed djangorestframework-3.13.1
